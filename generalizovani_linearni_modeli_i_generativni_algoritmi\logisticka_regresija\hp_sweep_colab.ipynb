# %% [markdown]
# <a href="https://colab.research.google.com/github/viktor-ktorvi/masinsko-ucenje-domaci/blob/master/generalizovani_linearni_modeli_i_generativni_algoritmi%5Clogisticka_regresija%5Chp_sweep_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/viktor-ktorvi/masinsko-ucenje-domaci.git
# Out:
# Cloning into 'masinsko-ucenje-domaci'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 143 (delta 66), reused 115 (delta 38), pack-reused 0
# Receiving objects: 100% (143/143), 293.34 KiB | 3.67 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
# !pwd
# !ls
# Out:
# /content/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci
# broj_indeksa.py
# data_loading
# generalizovani_linearni_modeli_i_generativni_algoritmi
# lokalno_ponderisana_linearna_regresija
# masinsko-ucenje-domaci
# utils

# %%
# %cd masinsko-ucenje-domaci
# Out:
# /content/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci

# %%
# !pip install wandb

# %%
# !python -m generalizovani_linearni_modeli_i_generativni_algoritmi.logisticka_regresija.hp_sweep
# Out:
# Create sweep with ID: a53papze
# Sweep URL: https://wandb.ai/viktor-ktorvi/mu-domaci-logisticka-regresija/sweeps/a53papze
# wandb: Agent Starting Run: wmqv9k5e with config:
# wandb: 	batch_size: 12
# wandb: 	lr: 0.0040334399682348775
# wandb: Currently logged in as: viktor-ktorvi. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/masinsko-ucenje-domaci/wandb/run-20221108_161828-wmqv9k5e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fancy-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/viktor-ktorvi/mu-domaci-logisticka-regresija
# ...
